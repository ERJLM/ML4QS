# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#%pip install regex
import regex as re

# %%
from Python3Code.Chapter4.FrequencyAbstraction import FourierTransformation
from Python3Code.Chapter4.TemporalAbstraction import NumericalAbstraction

# %%
df = pd.read_csv('data/dataset_imputed.csv')

# %% [markdown]
# ### Display the preview of our imputed data

# %%
# Display preview
print("Data Preview:")
display(df.head())
print("Columns:", df.columns.tolist())
# Out:
# Data Preview:
#    seconds_elapsed  z_accelerometer  y_accelerometer  x_accelerometer  \
# 0         0.040027        -0.273211        -0.279689        -0.342461
# 1         0.040460         1.260347        -0.319836        -0.342097
# 2         0.049252         1.260347        -0.319836        -0.342097
# 3         0.049960        -0.273211        -0.279689        -0.342461
# 4         0.059245         1.274834        -0.240963        -0.358970
#
#    z_gyroscope  y_gyroscope  x_gyroscope  user  z_accelerometer_lowpass  \
# 0     0.145889     0.136416     0.005533     3                -0.087919
# 1    -0.110204     0.161805    -0.306240     1                -0.094020
# 2    -0.110204     0.161805    -0.306240     1                -0.100092
# 3     0.145889     0.136416     0.005533     3                -0.106130
# 4    -0.145028     0.080974    -0.380480     1                -0.112131
#
#    y_accelerometer_lowpass  ...     pca_4     pca_5     pca_6     pca_7  \
# 0                -0.502079  ... -0.358698 -0.992872 -1.506684  0.264751
# 1                -0.499130  ... -0.143218 -1.130201 -1.464593  0.341156
# 2                -0.496159  ... -0.135123 -1.127834 -1.465137  0.352453
# 3                -0.493168  ... -0.334416 -0.985791 -1.508386  0.298638
# 4                -0.490155  ... -0.129642 -1.154960 -1.456594  0.324531
#
#       pca_8     pca_9    pca_10    pca_11    pca_12    pca_13
# 0  0.385887 -0.647561 -1.242256  0.212099  0.806083 -1.118422
# 1  0.633756 -0.420294 -1.484735  0.022319  0.635951 -1.051559
# 2  0.628880 -0.427888 -1.466034  0.014356  0.629667 -1.024100
# 3  0.371265 -0.670332 -1.186157  0.188215  0.787236 -1.036056
# 4  0.656941 -0.430889 -1.437520 -0.029626  0.617830 -0.974045
#
# [5 rows x 27 columns]
# Columns: ['seconds_elapsed', 'z_accelerometer', 'y_accelerometer', 'x_accelerometer', 'z_gyroscope', 'y_gyroscope', 'x_gyroscope', 'user', 'z_accelerometer_lowpass', 'y_accelerometer_lowpass', 'x_accelerometer_lowpass', 'z_gyroscope_lowpass', 'y_gyroscope_lowpass', 'x_gyroscope_lowpass', 'pca_1', 'pca_2', 'pca_3', 'pca_4', 'pca_5', 'pca_6', 'pca_7', 'pca_8', 'pca_9', 'pca_10', 'pca_11', 'pca_12', 'pca_13']

# %% [markdown]
# ### Temporal Abstraction

# %%
columns_to_transform = ['z_accelerometer_lowpass', 'y_accelerometer_lowpass', 'x_accelerometer_lowpass', 'z_gyroscope_lowpass', 'y_gyroscope_lowpass', 'x_gyroscope_lowpass', 'z_accelerometer', 'y_accelerometer', 'x_accelerometer', 'z_gyroscope', 'y_gyroscope', 'x_gyroscope']  # change to your actual column names
# Example configuration — adjust based on your sampling and signals
window_size = 40  # should match your time-series resolution
sampling_rate = 100  # Hz, change this to your sensor's rate

# %% [markdown]
# ##### Add the features per user

# %%
na = NumericalAbstraction()
processed_users = []

# Process the data by user
for user in df.user.unique():
    user_mask = df.user == user
    user_df = df[user_mask].copy()

    user_df = na.abstract_numerical(data_table=user_df, cols=columns_to_transform, window_size=window_size, aggregation_function_name='mean')
    user_df = na.abstract_numerical(data_table=user_df, cols=columns_to_transform, window_size=window_size, aggregation_function_name='std')
    user_df = na.abstract_numerical(data_table=user_df, cols=columns_to_transform, window_size=window_size, aggregation_function_name='min')
    user_df = na.abstract_numerical(data_table=user_df, cols=columns_to_transform, window_size=window_size, aggregation_function_name='max')

    processed_users.append(user_df)

# Recombine all processed user data
df = pd.concat(processed_users).sort_index()
df
# Out:
#         seconds_elapsed  z_accelerometer  y_accelerometer  x_accelerometer  \
# 0              0.040027        -0.273211        -0.279689        -0.342461
# 1              0.040460         1.260347        -0.319836        -0.342097
# 2              0.049252         1.260347        -0.319836        -0.342097
# 3              0.049960        -0.273211        -0.279689        -0.342461
# 4              0.059245         1.274834        -0.240963        -0.358970
# ...                 ...              ...              ...              ...
# 232641       775.538496        -0.992985        -5.758652         4.859346
# 232642       775.539918        -7.387298        -8.144462         0.807643
# 232643       775.544682         0.172228        -0.416443         0.286711
# 232644       775.548429        -0.732786        -5.806568         5.015984
# 232645       775.549886        -6.896828        -7.562372         1.164219
#
#         z_gyroscope  y_gyroscope  x_gyroscope  user  z_accelerometer_lowpass  \
# 0          0.145889     0.136416     0.005533     3                -0.087919
# 1         -0.110204     0.161805    -0.306240     1                -0.094020
# 2         -0.110204     0.161805    -0.306240     1                -0.100092
# 3          0.145889     0.136416     0.005533     3                -0.106130
# 4         -0.145028     0.080974    -0.380480     1                -0.112131
# ...             ...          ...          ...   ...                      ...
# 232641     1.199442    -0.058727     1.369393     3                -1.337381
# 232642    -0.370583    -1.712168    -0.019191     2                -1.338083
# 232643    -0.334846    -0.421050    -0.304001     1                -1.338672
# 232644     1.414098     0.109211     1.592959     3                -1.339158
# 232645    -0.567800    -1.236308     0.283564     2                -1.339553
#
#         y_accelerometer_lowpass  ...  x_accelerometer_lowpass_temp_max_ws_40  \
# 0                     -0.502079  ...                                     NaN
# 1                     -0.499130  ...                                     NaN
# 2                     -0.496159  ...                                     NaN
# 3                     -0.493168  ...                                     NaN
# 4                     -0.490155  ...                                     NaN
# ...                         ...  ...                                     ...
# 232641                 0.147406  ...                                0.333657
# 232642                 0.146336  ...                                0.333903
# 232643                 0.145438  ...                                0.334107
# 232644                 0.144694  ...                                0.334275
# 232645                 0.144089  ...                                0.334411
#
#         z_gyroscope_lowpass_temp_max_ws_40  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 232641                           -0.345793
# 232642                           -0.351329
# 232643                           -0.356845
# 232644                           -0.362338
# 232645                           -0.367805
#
#         y_gyroscope_lowpass_temp_max_ws_40  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 232641                            0.174361
# 232642                            0.174521
# 232643                            0.174461
# 232644                            0.174361
# 232645                            0.174521
#
#         x_gyroscope_lowpass_temp_max_ws_40  z_accelerometer_temp_max_ws_40  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                      NaN                             NaN
# ...                                    ...                             ...
# 232641                           -0.558866                        5.432712
# 232642                           -0.574431                        7.008690
# 232643                           -0.589739                        2.472252
# 232644                           -0.604784                        4.298582
# 232645                           -0.619559                        6.883648
#
#         y_accelerometer_temp_max_ws_40  x_accelerometer_temp_max_ws_40  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
# ...                                ...                             ...
# 232641                        2.351401                        4.859346
# 232642                        8.385260                        8.410290
# 232643                        1.391907                        0.286711
# 232644                        2.351401                        5.015984
# 232645                        8.385260                        8.410290
#
#         z_gyroscope_temp_max_ws_40  y_gyroscope_temp_max_ws_40  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 232641                    1.199442                    3.424362
# 232642                    0.494739                    1.324911
# 232643                   -0.135751                    0.047113
# 232644                    1.414098                    3.424362
# 232645                    0.264015                    1.324911
#
#         x_gyroscope_temp_max_ws_40
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 232641                    1.369393
# 232642                   -0.019191
# 232643                    0.599179
# 232644                    1.592959
# 232645                    0.283564
#
# [232646 rows x 75 columns]

# %% [markdown]
# ### Frequency Abstraction

# %% [markdown]
# Set up for FTT.
# Single user per process

# %%
# Apply Fourier Transformation
ft = FourierTransformation()
processed_users = []

for user in df.user.unique():
    user_mask = df.user == user
    user_df = df[user_mask].copy()

    user_df = ft.abstract_frequency(
        data_table=user_df,
        columns=columns_to_transform,
        window_size=window_size,
        sampling_rate=sampling_rate
    )

    processed_users.append(user_df)

# Recombine all processed user data
df = pd.concat(processed_users).sort_index()
df
# Out:
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
# /Users/eliandromelo/MSc_CS/ML4QS/src/Python3Code/Chapter4/FrequencyAbstraction.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[collist] = pd.DataFrame(frequencies, index=data_table.index)
#         seconds_elapsed  z_accelerometer  y_accelerometer  x_accelerometer  \
# 0              0.040027        -0.273211        -0.279689        -0.342461
# 1              0.040460         1.260347        -0.319836        -0.342097
# 2              0.049252         1.260347        -0.319836        -0.342097
# 3              0.049960        -0.273211        -0.279689        -0.342461
# 4              0.059245         1.274834        -0.240963        -0.358970
# ...                 ...              ...              ...              ...
# 232641       775.538496        -0.992985        -5.758652         4.859346
# 232642       775.539918        -7.387298        -8.144462         0.807643
# 232643       775.544682         0.172228        -0.416443         0.286711
# 232644       775.548429        -0.732786        -5.806568         5.015984
# 232645       775.549886        -6.896828        -7.562372         1.164219
#
#         z_gyroscope  y_gyroscope  x_gyroscope  user  z_accelerometer_lowpass  \
# 0          0.145889     0.136416     0.005533     3                -0.087919
# 1         -0.110204     0.161805    -0.306240     1                -0.094020
# 2         -0.110204     0.161805    -0.306240     1                -0.100092
# 3          0.145889     0.136416     0.005533     3                -0.106130
# 4         -0.145028     0.080974    -0.380480     1                -0.112131
# ...             ...          ...          ...   ...                      ...
# 232641     1.199442    -0.058727     1.369393     3                -1.337381
# 232642    -0.370583    -1.712168    -0.019191     2                -1.338083
# 232643    -0.334846    -0.421050    -0.304001     1                -1.338672
# 232644     1.414098     0.109211     1.592959     3                -1.339158
# 232645    -0.567800    -1.236308     0.283564     2                -1.339553
#
#         y_accelerometer_lowpass  ...  x_gyroscope_freq_27.5_Hz_ws_40  \
# 0                     -0.502079  ...                             NaN
# 1                     -0.499130  ...                             NaN
# 2                     -0.496159  ...                             NaN
# 3                     -0.493168  ...                             NaN
# 4                     -0.490155  ...                             NaN
# ...                         ...  ...                             ...
# 232641                 0.147406  ...                       -1.756484
# 232642                 0.146336  ...                       -0.081609
# 232643                 0.145438  ...                        0.200181
# 232644                 0.144694  ...                       -2.191315
# 232645                 0.144089  ...                       -0.362585
#
#         x_gyroscope_freq_30.0_Hz_ws_40  x_gyroscope_freq_32.5_Hz_ws_40  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
# ...                                ...                             ...
# 232641                       -1.835327                       -1.676813
# 232642                       -0.366085                       -0.257498
# 232643                        0.292764                        0.318034
# 232644                       -2.116063                       -2.358711
# 232645                       -0.674860                       -0.459265
#
#         x_gyroscope_freq_35.0_Hz_ws_40  x_gyroscope_freq_37.5_Hz_ws_40  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
# ...                                ...                             ...
# 232641                       -1.806152                       -1.818741
# 232642                       -0.277366                       -0.286400
# 232643                        0.220598                        0.134340
# 232644                       -2.283660                       -2.258479
# 232645                       -0.568511                       -0.596049
#
#         x_gyroscope_freq_40.0_Hz_ws_40  x_gyroscope_freq_42.5_Hz_ws_40  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
# ...                                ...                             ...
# 232641                       -1.880917                       -1.797777
# 232642                       -0.336105                       -0.286651
# 232643                        0.207274                        0.237348
# 232644                       -2.155638                       -2.221200
# 232645                       -0.565836                       -0.592414
#
#         x_gyroscope_freq_45.0_Hz_ws_40  x_gyroscope_freq_47.5_Hz_ws_40  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
# ...                                ...                             ...
# 232641                       -1.850762                       -1.890624
# 232642                       -0.273499                       -0.273911
# 232643                        0.203494                        0.181727
# 232644                       -2.232408                       -2.212610
# 232645                       -0.626673                       -0.664108
#
#         x_gyroscope_freq_50.0_Hz_ws_40
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 232641                       -1.985770
# 232642                       -0.286809
# 232643                        0.187381
# 232644                       -2.124797
# 232645                       -0.651636
#
# [232646 rows x 363 columns]

# %% [markdown]
# ### Let's remove the added missing values

# %%
df = df.dropna()
df
# Out:
#         seconds_elapsed  z_accelerometer  y_accelerometer  x_accelerometer  \
# 114            0.438087        -0.606554         0.896955        -1.459795
# 115            0.439011        -0.651863         0.687298         0.363176
# 117            0.448021        -0.427877         0.661085        -1.474408
# 118            0.449005        -0.260615         0.538511         0.417578
# 120            0.457955        -0.249200         0.425215        -1.489022
# ...                 ...              ...              ...              ...
# 232641       775.538496        -0.992985        -5.758652         4.859346
# 232642       775.539918        -7.387298        -8.144462         0.807643
# 232643       775.544682         0.172228        -0.416443         0.286711
# 232644       775.548429        -0.732786        -5.806568         5.015984
# 232645       775.549886        -6.896828        -7.562372         1.164219
#
#         z_gyroscope  y_gyroscope  x_gyroscope  user  z_accelerometer_lowpass  \
# 114        0.160653    -0.024878    -0.198946     3                 0.009262
# 115        0.236960    -0.257517     0.760620     1                 0.015715
# 117        0.104291    -0.052918    -0.176606     3                 0.028302
# 118        0.253509    -0.124384     0.701848     1                 0.034418
# 120        0.047929    -0.080958    -0.154265     3                 0.046258
# ...             ...          ...          ...   ...                      ...
# 232641     1.199442    -0.058727     1.369393     3                -1.337381
# 232642    -0.370583    -1.712168    -0.019191     2                -1.338083
# 232643    -0.334846    -0.421050    -0.304001     1                -1.338672
# 232644     1.414098     0.109211     1.592959     3                -1.339158
# 232645    -0.567800    -1.236308     0.283564     2                -1.339553
#
#         y_accelerometer_lowpass  ...  x_gyroscope_freq_27.5_Hz_ws_40  \
# 114                    0.088612  ...                       -0.001174
# 115                    0.091767  ...                       -0.505881
# 117                    0.097477  ...                        0.124298
# 118                    0.100028  ...                       -0.428012
# 120                    0.104514  ...                        0.173129
# ...                         ...  ...                             ...
# 232641                 0.147406  ...                       -1.756484
# 232642                 0.146336  ...                       -0.081609
# 232643                 0.145438  ...                        0.200181
# 232644                 0.144694  ...                       -2.191315
# 232645                 0.144089  ...                       -0.362585
#
#         x_gyroscope_freq_30.0_Hz_ws_40  x_gyroscope_freq_32.5_Hz_ws_40  \
# 114                          -0.008170                        0.053239
# 115                          -0.520236                       -0.554544
# 117                           0.069849                       -0.007237
# 118                          -0.437878                       -0.460331
# 120                           0.195635                        0.200188
# ...                                ...                             ...
# 232641                       -1.835327                       -1.676813
# 232642                       -0.366085                       -0.257498
# 232643                        0.292764                        0.318034
# 232644                       -2.116063                       -2.358711
# 232645                       -0.674860                       -0.459265
#
#         x_gyroscope_freq_35.0_Hz_ws_40  x_gyroscope_freq_37.5_Hz_ws_40  \
# 114                           0.121995                        0.173472
# 115                          -0.567485                       -0.574446
# 117                          -0.018529                       -0.009509
# 118                          -0.452051                       -0.445384
# 120                           0.167148                        0.127638
# ...                                ...                             ...
# 232641                       -1.806152                       -1.818741
# 232642                       -0.277366                       -0.286400
# 232643                        0.220598                        0.134340
# 232644                       -2.283660                       -2.258479
# 232645                       -0.568511                       -0.596049
#
#         x_gyroscope_freq_40.0_Hz_ws_40  x_gyroscope_freq_42.5_Hz_ws_40  \
# 114                           0.188852                        0.178741
# 115                          -0.534125                       -0.534210
# 117                           0.018068                        0.056638
# 118                          -0.475633                       -0.475844
# 120                           0.088691                        0.043387
# ...                                ...                             ...
# 232641                       -1.880917                       -1.797777
# 232642                       -0.336105                       -0.286651
# 232643                        0.207274                        0.237348
# 232644                       -2.155638                       -2.221200
# 232645                       -0.565836                       -0.592414
#
#         x_gyroscope_freq_45.0_Hz_ws_40  x_gyroscope_freq_47.5_Hz_ws_40  \
# 114                           0.117877                        0.042600
# 115                          -0.542236                       -0.557943
# 117                           0.098527                        0.155658
# 118                          -0.465259                       -0.446488
# 120                           0.029706                       -0.007994
# ...                                ...                             ...
# 232641                       -1.850762                       -1.890624
# 232642                       -0.273499                       -0.273911
# 232643                        0.203494                        0.181727
# 232644                       -2.232408                       -2.212610
# 232645                       -0.626673                       -0.664108
#
#         x_gyroscope_freq_50.0_Hz_ws_40
# 114                           0.005056
# 115                          -0.563961
# 117                           0.178766
# 118                          -0.443625
# 120                          -0.020071
# ...                                ...
# 232641                       -1.985770
# 232642                       -0.286809
# 232643                        0.187381
# 232644                       -2.124797
# 232645                       -0.651636
#
# [232526 rows x 363 columns]

# %%
len(df.columns)
# Out:
# 363

# %%
'''
# 5. Visualize Frequency Features
freq_cols = [col for col in df_transformed.columns if '_freq_' in col]

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df_transformed[freq_cols].corr(), cmap="coolwarm", center=0)
plt.title("Correlation between Fourier-derived Features")
plt.show()
'''
# Out:
# '\n# 5. Visualize Frequency Features\nfreq_cols = [col for col in df_transformed.columns if \'_freq_\' in col]\n\n# Correlation heatmap\nplt.figure(figsize=(12, 8))\nsns.heatmap(df_transformed[freq_cols].corr(), cmap="coolwarm", center=0)\nplt.title("Correlation between Fourier-derived Features")\nplt.show()\n'

# %%
# 6. Save output (optional)
#df_transformed.to_csv("user1_fourier_transformed_features.csv", index=False)
#print("Fourier-transformed features saved.")
